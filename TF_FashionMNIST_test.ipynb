# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

print(train_images.shape)
print(train_labels.shape)
print()
print(test_images.shape)
print(test_labels.shape)
# Out:
# (60000, 28, 28)
# (60000,)
#
# (10000, 28, 28)
# (10000,)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
len(class_names)
# Out:
# 10

# %%
#Scale data
train_images = train_images / 255.0
test_images = test_images / 255.0

plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(train_images[i], cmap=plt.cm.binary)
  plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ### Build Model

# %%
# model = keras.Sequential([
#                           keras.layers.Flatten(input_shape=(28, 28)),
#                           keras.layers.Dense(128, activation='relu'),
#                           keras.layers.Dense(128, activation='relu'),
#                           keras.layers.Dense(128, activation='relu'),                                                    
#                           keras.layers.Dense(10, activation='softmax')
# ])

# %%
# model.summary()

# %%
# model.compile(optimizer='adam',
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])

# %%
# model.fit(train_images, train_labels, epochs=100)

# %%
# test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)

# %% [markdown]
# ### **Testing few models**

# %%
Epochs = 300
model1_desc = ('4*128*relu, Epochs: ', Epochs)


model1 = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28, 28)),
                          keras.layers.Dense(128, activation='relu'),
                          keras.layers.Dense(128, activation='relu'),
                          keras.layers.Dense(128, activation='relu'),                                                    
                          keras.layers.Dense(10, activation='softmax')
])

model1.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model1.fit(train_images, train_labels, epochs=Epochs)

test_loss1, test_acc1 = model1.evaluate(test_images, test_labels, verbose=2)
print('Model:', model1_desc,'Test Loss: ',test_loss1, 'Test Accuracy: ', test_acc1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Train on 60000 samples
# Epoch 1/300
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.4852 - acc: 0.8258
# Epoch 2/300
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.3704 - acc: 0.8631
# Epoch 3/300
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.3348 - acc: 0.8758
# Epoch 4/300
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.3118 - acc: 0.8837
# Epoch 5/300
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.2950 - acc: 0.8895
# Epoch 6/300
# ...

# %%
Epochs = 200
model2_desc = ('4*128*relu, Epochs: ', Epochs)

model2 = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28, 28)),
                          keras.layers.Dense(128, activation='relu'),
                          keras.layers.Dense(128, activation='relu'),
                          keras.layers.Dense(128, activation='relu'),                                                    
                          keras.layers.Dense(10, activation='softmax')
])

model2.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model2.fit(train_images, train_labels, epochs=Epochs)

test_loss2, test_acc2 = model2.evaluate(test_images, test_labels, verbose=2)
print('Model2:', model2_desc,'Test Loss: ',test_loss2, 'Test Accuracy: ', test_acc2)
# Out:
# Train on 60000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.4878 - acc: 0.8239
# Epoch 2/200
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.3651 - acc: 0.8650
# Epoch 3/200
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.3331 - acc: 0.8760
# Epoch 4/200
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.3079 - acc: 0.8861
# Epoch 5/200
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.2899 - acc: 0.8913
# Epoch 6/200
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.2740 - acc: 0.8975
# Epoch 7/200
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.2636 - acc: 0.9017
# Epoch 8/200
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.2537 - acc: 0.9044
# Epoch 9/200
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.2442 - acc: 0.9067
# ...

# %%
Epochs = 50
model3_desc = ('4*256*relu, Epochs: ', Epochs)


model3 = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28, 28)),
                          keras.layers.Dense(256, activation='relu'),
                          keras.layers.Dense(256, activation='relu'),
                          keras.layers.Dense(256, activation='relu'),                                                    
                          keras.layers.Dense(10, activation='softmax')
])

model3.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model3.fit(train_images, train_labels, epochs=Epochs)

test_loss3, test_acc3 = model3.evaluate(test_images, test_labels, verbose=2)
print('Model:', model3_desc,'Test Loss: ',test_loss3, 'Test Accuracy: ', test_acc3)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 8s 130us/sample - loss: 0.4775 - acc: 0.8255
# Epoch 2/50
# 60000/60000 [==============================] - 8s 132us/sample - loss: 0.3625 - acc: 0.8663
# Epoch 3/50
# 60000/60000 [==============================] - 8s 128us/sample - loss: 0.3281 - acc: 0.8784
# Epoch 4/50
# 60000/60000 [==============================] - 8s 128us/sample - loss: 0.3029 - acc: 0.8871
# Epoch 5/50
# 60000/60000 [==============================] - 8s 134us/sample - loss: 0.2850 - acc: 0.8948
# Epoch 6/50
# 60000/60000 [==============================] - 8s 127us/sample - loss: 0.2711 - acc: 0.8987
# Epoch 7/50
# 60000/60000 [==============================] - 8s 128us/sample - loss: 0.2586 - acc: 0.9013
# Epoch 8/50
# 60000/60000 [==============================] - 8s 131us/sample - loss: 0.2457 - acc: 0.9066
# Epoch 9/50
# 60000/60000 [==============================] - 8s 131us/sample - loss: 0.2370 - acc: 0.9107
# ...

# %%
Epochs = 100
model4_desc = ('2*512*relu, Epochs: ', Epochs)

model4 = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28, 28)),
                          keras.layers.Dense(512, activation='relu'),
                          keras.layers.Dense(512, activation='relu'),                                               
                          keras.layers.Dense(10, activation='softmax')
])

model4.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model4.fit(train_images, train_labels, epochs=Epochs)

test_loss4, test_acc4 = model4.evaluate(test_images, test_labels, verbose=2)
print('2*512*relu')
print('Model:', model4_desc,'Test Loss: ',test_loss4, 'Test Accuracy: ', test_acc4)
# Out:
# Train on 60000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 12s 199us/sample - loss: 0.4669 - acc: 0.8294
# Epoch 2/100
# 60000/60000 [==============================] - 12s 196us/sample - loss: 0.3586 - acc: 0.8690
# Epoch 3/100
# 60000/60000 [==============================] - 12s 195us/sample - loss: 0.3204 - acc: 0.8812
# Epoch 4/100
# 60000/60000 [==============================] - 12s 198us/sample - loss: 0.2932 - acc: 0.8918
# Epoch 5/100
# 60000/60000 [==============================] - 12s 197us/sample - loss: 0.2769 - acc: 0.8953
# Epoch 6/100
# 60000/60000 [==============================] - 12s 200us/sample - loss: 0.2649 - acc: 0.9001
# Epoch 7/100
# 60000/60000 [==============================] - 12s 199us/sample - loss: 0.2491 - acc: 0.9062
# Epoch 8/100
# 60000/60000 [==============================] - 12s 200us/sample - loss: 0.2399 - acc: 0.9096
# Epoch 9/100
# ...

# %%
Epochs = 50
model5_desc =  ('2*128*sigmoid, Epochs: ', Epochs)


model5 = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28, 28)),
                          keras.layers.Dense(128, activation='sigmoid'),
                          keras.layers.Dense(128, activation='sigmoid'),                                                   
                          keras.layers.Dense(10, activation='softmax')
])

model5.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model5.fit(train_images, train_labels, epochs=Epochs)

test_loss5, test_acc5 = model5.evaluate(test_images, test_labels, verbose=2)
print('Model:', model5_desc,'Test Loss: ',test_loss5, 'Test Accuracy: ', test_acc5)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.5835 - acc: 0.7982
# Epoch 2/50
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.3855 - acc: 0.8594
# Epoch 3/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.3487 - acc: 0.8732
# Epoch 4/50
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.3256 - acc: 0.8808
# Epoch 5/50
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.3082 - acc: 0.8874
# Epoch 6/50
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.2921 - acc: 0.8922
# Epoch 7/50
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.2812 - acc: 0.8952
# Epoch 8/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.2686 - acc: 0.9002
# Epoch 9/50
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.2572 - acc: 0.9043
# Epoch 10/50
# ...

# %%
Epochs = 50
model6_desc =  ('10*128*relu, Epochs: ', Epochs)


model6 = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28, 28)),
                          keras.layers.Dense(128, activation='relu'), #1
                          keras.layers.Dense(128, activation='relu'), #2
                          keras.layers.Dense(128, activation='relu'), #3
                          keras.layers.Dense(128, activation='relu'), #4
                          keras.layers.Dense(128, activation='relu'), #5
                          keras.layers.Dense(128, activation='relu'), #6
                          keras.layers.Dense(128, activation='relu'), #7
                          keras.layers.Dense(128, activation='relu'), #8
                          keras.layers.Dense(128, activation='relu'), #9
                          keras.layers.Dense(128, activation='relu'), #10                                                                                                                                                                                                                                       
                          keras.layers.Dense(10, activation='softmax')
])

model6.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model6.fit(train_images, train_labels, epochs=Epochs)

test_loss6, test_acc6 = model6.evaluate(test_images, test_labels, verbose=2)
print('Model:', model6_desc,'Test Loss: ',test_loss6, 'Test Accuracy: ', test_acc6)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 8s 138us/sample - loss: 0.6053 - acc: 0.7749
# Epoch 2/50
# 60000/60000 [==============================] - 8s 134us/sample - loss: 0.4332 - acc: 0.8468
# Epoch 3/50
# 60000/60000 [==============================] - 8s 133us/sample - loss: 0.3862 - acc: 0.8640
# Epoch 4/50
# 60000/60000 [==============================] - 8s 136us/sample - loss: 0.3693 - acc: 0.8701
# Epoch 5/50
# 60000/60000 [==============================] - 8s 137us/sample - loss: 0.3448 - acc: 0.8766
# Epoch 6/50
# 60000/60000 [==============================] - 8s 136us/sample - loss: 0.3348 - acc: 0.8811
# Epoch 7/50
# 60000/60000 [==============================] - 8s 137us/sample - loss: 0.3199 - acc: 0.8857
# Epoch 8/50
# 60000/60000 [==============================] - 8s 138us/sample - loss: 0.3080 - acc: 0.8896
# Epoch 9/50
# 60000/60000 [==============================] - 8s 135us/sample - loss: 0.3021 - acc: 0.8911
# ...

# %%
Epochs = 500
model7_desc =  ('10*128*relu, Epochs: ', Epochs)


model7 = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28, 28)),
                          keras.layers.Dense(128, activation='relu'), #1
                          keras.layers.Dense(128, activation='relu'), #2
                          keras.layers.Dense(128, activation='relu'), #3
                          keras.layers.Dense(128, activation='relu'), #4
                          keras.layers.Dense(128, activation='relu'), #5
                          keras.layers.Dense(128, activation='relu'), #6
                          keras.layers.Dense(128, activation='relu'), #7
                          keras.layers.Dense(128, activation='relu'), #8
                          keras.layers.Dense(128, activation='relu'), #9
                          keras.layers.Dense(128, activation='relu'), #10                                                                                                                                                                                                                                       
                          keras.layers.Dense(10, activation='softmax')
])

model7.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model7.fit(train_images, train_labels, epochs=Epochs)

test_loss7, test_acc7 = model7.evaluate(test_images, test_labels, verbose=2)
print('Model:', model7_desc,'Test Loss: ',test_loss7, 'Test Accuracy: ', test_acc7)
# Out:
# Train on 60000 samples
# Epoch 1/500
# 60000/60000 [==============================] - 9s 143us/sample - loss: 0.5983 - acc: 0.7787
# Epoch 2/500
# 60000/60000 [==============================] - 8s 140us/sample - loss: 0.4253 - acc: 0.8488
# Epoch 3/500
# 60000/60000 [==============================] - 8s 140us/sample - loss: 0.3836 - acc: 0.8638
# Epoch 4/500
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.3626 - acc: 0.8729
# Epoch 5/500
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.3417 - acc: 0.8796
# Epoch 6/500
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.3295 - acc: 0.8813
# Epoch 7/500
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.3178 - acc: 0.8869
# Epoch 8/500
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.3066 - acc: 0.8910
# Epoch 9/500
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.3007 - acc: 0.8920
# ...

# %%
Epochs = 50
model8_desc =  ('20*128*relu, Epochs: ', Epochs)


model8 = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28, 28)),
                          keras.layers.Dense(128, activation='relu'), #1
                          keras.layers.Dense(128, activation='relu'), #2
                          keras.layers.Dense(128, activation='relu'), #3
                          keras.layers.Dense(128, activation='relu'), #4
                          keras.layers.Dense(128, activation='relu'), #5
                          keras.layers.Dense(128, activation='relu'), #6
                          keras.layers.Dense(128, activation='relu'), #7
                          keras.layers.Dense(128, activation='relu'), #8
                          keras.layers.Dense(128, activation='relu'), #9
                          keras.layers.Dense(128, activation='relu'), #10   
                          keras.layers.Dense(128, activation='relu'), #11 
                          keras.layers.Dense(128, activation='relu'), #12 
                          keras.layers.Dense(128, activation='relu'), #13 
                          keras.layers.Dense(128, activation='relu'), #14 
                          keras.layers.Dense(128, activation='relu'), #15 
                          keras.layers.Dense(128, activation='relu'), #16 
                          keras.layers.Dense(128, activation='relu'), #17 
                          keras.layers.Dense(128, activation='relu'), #18 
                          keras.layers.Dense(128, activation='relu'), #19  
                          keras.layers.Dense(128, activation='relu'), #20
                          keras.layers.Dense(10, activation='softmax')
])

model8.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model8.fit(train_images, train_labels, epochs=Epochs)

test_loss8, test_acc8 = model8.evaluate(test_images, test_labels, verbose=2)
print('Model:', model8_desc,'Test Loss: ',test_loss8, 'Test Accuracy: ', test_acc8)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 14s 237us/sample - loss: 0.9516 - acc: 0.6176
# Epoch 2/50
# 60000/60000 [==============================] - 14s 233us/sample - loss: 0.6631 - acc: 0.7583
# Epoch 3/50
# 60000/60000 [==============================] - 14s 229us/sample - loss: 0.6885 - acc: 0.7568
# Epoch 4/50
# 60000/60000 [==============================] - 14s 232us/sample - loss: 0.7297 - acc: 0.7377
# Epoch 5/50
# 60000/60000 [==============================] - 14s 233us/sample - loss: 0.6702 - acc: 0.7615
# Epoch 6/50
# 60000/60000 [==============================] - 14s 231us/sample - loss: 0.7070 - acc: 0.7441
# Epoch 7/50
# 60000/60000 [==============================] - 14s 238us/sample - loss: 0.7968 - acc: 0.7202
# Epoch 8/50
# 60000/60000 [==============================] - 15s 244us/sample - loss: 0.7307 - acc: 0.7412
# Epoch 9/50
# 60000/60000 [==============================] - 14s 234us/sample - loss: 0.6848 - acc: 0.7481
# ...

# %%
Epochs = 50
model9_desc =  ('15*128*relu, Epochs: ', Epochs)


model9 = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28, 28)),
                          keras.layers.Dense(128, activation='relu'), #1
                          keras.layers.Dense(128, activation='relu'), #2
                          keras.layers.Dense(128, activation='relu'), #3
                          keras.layers.Dense(128, activation='relu'), #4
                          keras.layers.Dense(128, activation='relu'), #5
                          keras.layers.Dense(128, activation='relu'), #6
                          keras.layers.Dense(128, activation='relu'), #7
                          keras.layers.Dense(128, activation='relu'), #8
                          keras.layers.Dense(128, activation='relu'), #9
                          keras.layers.Dense(128, activation='relu'), #10   
                          keras.layers.Dense(128, activation='relu'), #11 
                          keras.layers.Dense(128, activation='relu'), #12 
                          keras.layers.Dense(128, activation='relu'), #13 
                          keras.layers.Dense(128, activation='relu'), #14 
                          keras.layers.Dense(128, activation='relu'), #15 
                          keras.layers.Dense(10, activation='softmax')
])

model9.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model9.fit(train_images, train_labels, epochs=Epochs)

test_loss9, test_acc9 = model9.evaluate(test_images, test_labels, verbose=2)
print('Model:', model9_desc,'Test Loss: ',test_loss9, 'Test Accuracy: ', test_acc9)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 13s 224us/sample - loss: 0.6977 - acc: 0.7325
# Epoch 2/50
# 60000/60000 [==============================] - 11s 189us/sample - loss: 0.5190 - acc: 0.8200
# Epoch 3/50
# 60000/60000 [==============================] - 11s 190us/sample - loss: 0.4596 - acc: 0.8414
# Epoch 4/50
# 60000/60000 [==============================] - 11s 191us/sample - loss: 0.4431 - acc: 0.8471
# Epoch 5/50
# 60000/60000 [==============================] - 11s 189us/sample - loss: 0.4032 - acc: 0.8615
# Epoch 6/50
# 60000/60000 [==============================] - 12s 194us/sample - loss: 0.4063 - acc: 0.8596
# Epoch 7/50
# 60000/60000 [==============================] - 12s 196us/sample - loss: 0.3867 - acc: 0.8675
# Epoch 8/50
# 60000/60000 [==============================] - 11s 189us/sample - loss: 0.3698 - acc: 0.8721
# Epoch 9/50
# 60000/60000 [==============================] - 11s 191us/sample - loss: 0.3635 - acc: 0.8733
# ...

# %%
Epochs = 50
model10_desc =  ('1*784*relu, Epochs: ', Epochs)


model10 = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28, 28)),
                          keras.layers.Dense(784, activation='relu'), #1
                          keras.layers.Dense(10, activation='softmax')
])

model10.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model10.fit(train_images, train_labels, epochs=Epochs)

test_loss10, test_acc10 = model10.evaluate(test_images, test_labels, verbose=2)
print('Model10:', model10_desc,'Test Loss: ',test_loss10, 'Test Accuracy: ', test_acc10)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 10s 166us/sample - loss: 0.4745 - acc: 0.8309
# Epoch 2/50
# 60000/60000 [==============================] - 10s 163us/sample - loss: 0.3558 - acc: 0.8686
# Epoch 3/50
# 60000/60000 [==============================] - 10s 162us/sample - loss: 0.3198 - acc: 0.8809
# Epoch 4/50
# 60000/60000 [==============================] - 10s 168us/sample - loss: 0.2971 - acc: 0.8899
# Epoch 5/50
# 60000/60000 [==============================] - 10s 170us/sample - loss: 0.2762 - acc: 0.8965
# Epoch 6/50
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.2632 - acc: 0.9018
# Epoch 7/50
# 60000/60000 [==============================] - 10s 162us/sample - loss: 0.2508 - acc: 0.9061
# Epoch 8/50
# 60000/60000 [==============================] - 10s 163us/sample - loss: 0.2396 - acc: 0.9102
# Epoch 9/50
# 60000/60000 [==============================] - 10s 163us/sample - loss: 0.2276 - acc: 0.9147
# ...

# %%
print('Model1:', model1_desc,'Test Loss: ',test_loss1, 'Test Accuracy: ', test_acc1)
print('Model2:', model2_desc,'Test Loss: ',test_loss2, 'Test Accuracy: ', test_acc2)
print('Model3:', model3_desc,'Test Loss: ',test_loss3, 'Test Accuracy: ', test_acc3)
print('Model4:', model4_desc,'Test Loss: ',test_loss4, 'Test Accuracy: ', test_acc4)
print('Model5:', model5_desc,'Test Loss: ',test_loss5, 'Test Accuracy: ', test_acc5)
print('Model6:', model6_desc,'Test Loss: ',test_loss6, 'Test Accuracy: ', test_acc6)
print('Model7:', model7_desc,'Test Loss: ',test_loss7, 'Test Accuracy: ', test_acc7)
print('Model8:', model8_desc,'Test Loss: ',test_loss8, 'Test Accuracy: ', test_acc8)
print('Model9:', model9_desc,'Test Loss: ',test_loss9, 'Test Accuracy: ', test_acc9)
print('Model0:', model10_desc,'Test Loss: ',test_loss10, 'Test Accuracy: ', test_acc10)
# Out:
# Model1: ('4*128*relu, Epochs: ', 300) Test Loss:  2.5143374368944205 Test Accuracy:  0.8903
# Model2: ('4*128*relu, Epochs: ', 200) Test Loss:  1.7939598450653256 Test Accuracy:  0.8869
# Model3: ('4*256*relu, Epochs: ', 50) Test Loss:  0.70717086187182 Test Accuracy:  0.8956
# Model4: ('2*512*relu, Epochs: ', 100) Test Loss:  1.2782225279907187 Test Accuracy:  0.888
# Model5: ('2*128*sigmoid, Epochs: ', 50) Test Loss:  0.4885916341423988 Test Accuracy:  0.8878
# Model6: ('10*128*relu, Epochs: ', 50) Test Loss:  0.48149377764463425 Test Accuracy:  0.8965
# Model7: ('10*128*relu, Epochs: ', 500) Test Loss:  1.5819290552724152 Test Accuracy:  0.89
# Model8: ('20*128*relu, Epochs: ', 50) Test Loss:  0.3971658544540405 Test Accuracy:  0.8735
# Model9: ('15*128*relu, Epochs: ', 50) Test Loss:  0.4759584278583527 Test Accuracy:  0.8383
# Model: ('1*784*relu, Epochs: ', 50) Test Loss:  0.5700376505934167 Test Accuracy:  0.8909

# %% [markdown]
# ### **End of model testing**

# %%
predictions = model6.predict(test_images)

# %%
predictions[0]
# Out:
# array([0.09675505, 0.09576144, 0.1001905 , 0.09424067, 0.0973144 ,
#        0.10410788, 0.09832785, 0.10459175, 0.10282232, 0.1058882 ],
#       dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                        100*np.max(predictions_array),
                                        class_names[true_label]),
                                        color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color='#777777')
  plt.ylim([0,1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i], test_labels)

# %%
num_rows = 5
num_cols = 3
num_images = num_rows * num_cols

plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)

plt.tight_layout()
plt.show()

# %%
img = test_images[1]
print(img.shape)

img = (np.expand_dims(img, 0))
print(img.shape)
# Out:
# (28, 28)
# (1, 28, 28)

# %%
predictions_single = model6.predict(img)
print(predictions_single)
print(len(predictions_single))
print(type(predictions_single))
# Out:
# [[0.09798701 0.09555954 0.10071474 0.09610698 0.09900641 0.10119867
#   0.09922244 0.10272302 0.10264528 0.10483594]]
# 1
# <class 'numpy.ndarray'>

# %%
plot_value_array(1, predictions_single[0], test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)

# %%
np.argmax(predictions_single[0])
# Out:
# 9
